# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
dts1=pd.read_csv(r"C:\Users\pawar\Downloads\Loan_Data.csv")

# %%
dts1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
dts1.isnull().sum()/dts1.shape[0]*100
# Out:
# Loan_ID              0.000000
# Gender               2.117264
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       8.143322
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
dts1=dts1.dropna()
dts1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
dts1.isnull().sum()
dts1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
dts1.loc[dts1["Gender"] == "Male", "Gender"] = 1
dts1.loc[dts1["Gender"] == "Female", "Gender"] = 0
dts1.loc[dts1["Self_Employed"] == "Yes", "Self_Employed"] = 1
dts1.loc[dts1["Self_Employed"] == "No", "Self_Employed"] = 0
dts1.loc[dts1["Education"] == "Graduate", "Education"] = 1
dts1.loc[dts1["Education"] == "Not Graduate", "Education"] = 0




dts1
#dts1=dts1.drop("Loan_ID",axis="columns")
# dts1=pd.get_dummies(dts1)
# dts1
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 1    LP001003      1     Yes          1         1             0
# 2    LP001005      1     Yes          0         1             1
# 3    LP001006      1     Yes          0         0             0
# 4    LP001008      1      No          0         1             0
# 5    LP001011      1     Yes          2         1             1
# ..        ...    ...     ...        ...       ...           ...
# 609  LP002978      0      No          0         1             0
# 610  LP002979      1     Yes         3+         1             0
# 611  LP002983      1     Yes          1         1             0
# 612  LP002984      1     Yes          2         1             0
# 613  LP002990      0      No          0         1             1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# ...

# %%
dts1=dts1.drop("Married",axis="columns")
dts1=dts1.drop("Property_Area",axis="columns")

# %%
dts1=dts1.drop("Loan_ID",axis="columns")
dts1=dts1.drop("Dependents",axis="columns")

# %%
X=dts1.drop("Loan_Status",axis="columns")
y=dts1.iloc[:,-1:]
y
# Out:
#     Loan_Status
# 1             N
# 2             Y
# 3             Y
# 4             Y
# 5             Y
# ..          ...
# 609           Y
# 610           Y
# 611           Y
# 612           Y
# 613           N
#
# [480 rows x 1 columns]

# %%
dts1
# Out:
#     Gender Education Self_Employed  ApplicantIncome  CoapplicantIncome  \
# 1        1         1             0             4583             1508.0
# 2        1         1             1             3000                0.0
# 3        1         0             0             2583             2358.0
# 4        1         1             0             6000                0.0
# 5        1         1             1             5417             4196.0
# ..     ...       ...           ...              ...                ...
# 609      0         1             0             2900                0.0
# 610      1         1             0             4106                0.0
# 611      1         1             0             8072              240.0
# 612      1         1             0             7583                0.0
# 613      0         1             1             4583                0.0
#
#      LoanAmount  Loan_Amount_Term  Credit_History Loan_Status
# ...

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=51)

# %%
from sklearn.linear_model import LogisticRegression

# %%
gnb=LogisticRegression()

# %%
gnb.fit(X_train,y_train)
# Out:
# C:\Users\pawar\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
gnb.score(X_test,y_test)
# Out:
# 0.8020833333333334

# %%
gnb.predict(X_test[0:])
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y'], dtype=object)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()

# %%
dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtc.score(X_test,y_test)
# Out:
# 0.7083333333333334

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(X_train,y_train)
# Out:
# C:\Users\pawar\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
rfc.score(X_test,y_test)
# Out:
# 0.78125

# %%
rfc.predict(X_test)
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y'], dtype=object)
